# %%
from bs4 import BeautifulSoup
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from webdriver_manager.chrome import ChromeDriverManager
from selenium.webdriver.common.by import By
from selenium.webdriver.chrome.options import Options
from selenium.common.exceptions import NoSuchElementException, StaleElementReferenceException


import time
from datetime import datetime
import json

options = Options()
options.headless = True  # Running in headless mode
options.add_experimental_option("prefs", {
    # disable images for speed
    "profile.managed_default_content_settings.images": 2,  
    # disable video features
    "profile.default_content_setting_values.media_stream": 2,
    "profile.default_content_setting_values.media_stream_mic": 2,
    "profile.default_content_setting_values.media_stream_camera": 2,
    "profile.default_content_setting_values.durable_storage": 2
})
options.page_load_strategy = 'eager'  # Set page load strategy to 'eager'
# Out:
# C:\Users\Danil\AppData\Local\Temp\ipykernel_17960\734446527.py:15: DeprecationWarning: headless property is deprecated, instead use add_argument('--headless') or add_argument('--headless=new')
#   options.headless = True  # Running in headless mode

# %%
ChromeDriverManager.install()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# c:\Users\Danil\Documents\GitHub\twitch-chat-analytics\twitch_listener.ipynb Cell 2 line 1
# ----> <a href='vscode-notebook-cell:/c%3A/Users/Danil/Documents/GitHub/twitch-chat-analytics/twitch_listener.ipynb#X10sZmlsZQ%3D%3D?line=0'>1</a> ChromeDriverManager.install()
#
# TypeError: install() missing 1 required positional argument: 'self'

# %%
service = Service(ChromeDriverManager().install())
driver = webdriver.Chrome(service=service, options=options)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# c:\Users\Danil\Documents\GitHub\twitch-chat-analytics\twitch_listener.ipynb Cell 3 line 2
#       <a href='vscode-notebook-cell:/c%3A/Users/Danil/Documents/GitHub/twitch-chat-analytics/twitch_listener.ipynb#W1sZmlsZQ%3D%3D?line=0'>1</a> driver_path ='C:/Users/Danil/Desktop/Programming/Chromedriver/chromedriver_win32/chromedriver'
# ----> <a href='vscode-notebook-cell:/c%3A/Users/Danil/Documents/GitHub/twitch-chat-analytics/twitch_listener.ipynb#W1sZmlsZQ%3D%3D?line=1'>2</a> driver = webdriver.Chrome(ChromeDriverManager().install())
#
# File c:\Users\Danil\anaconda3\lib\site-packages\webdriver_manager\chrome.py:39, in ChromeDriverManager.install(self)
#      38 def install(self) -> str:
# ---> 39     driver_path = self._get_driver_path(self.driver)
#      40     os.chmod(driver_path, 0o755)
#      41     return driver_path
#
# File c:\Users\Danil\anaconda3\lib\site-packages\webdriver_manager\core\manager.py:30, in DriverManager._get_driver_path(self, driver)
#      27 if binary_path:
#      28     return binary_path
# ---> 30 file = self._download_manager.download_file(driver.get_driver_download_url())
#      31 binary_path = self.driver_cache.save_file_to_cache(driver, file)
#      32 return binary_path
#
# File c:\Users\Danil\anaconda3\lib\site-packages\webdriver_manager\drivers\chrome.py:40, in ChromeDriver.get_driver_download_url(self)
#      39 def get_driver_download_url(self):
# ---> 40     driver_version_to_download = self.get_driver_version_to_download()
#      41     os_type = self._os_type
#      42     # For Mac ARM CPUs after version 106.0.5249.61 the format of OS type changed
#      43     # to more unified "mac_arm64". For newer versions, it'll be "mac_arm64"
#      44     # by default, for lower versions we replace "mac_arm64" to old format - "mac64_m1".
#
# File c:\Users\Danil\anaconda3\lib\site-packages\webdriver_manager\core\driver.py:51, in Driver.get_driver_version_to_download(self)
#      45 """
#      46 Downloads version from parameter if version not None or "latest".
#      47 Downloads latest, if version is "latest" or browser could not been determined.
#      48 Downloads determined browser version driver in all other ways as a bonus fallback for lazy users.
#      49 """
#      50 if not self._driver_to_download_version:
# ---> 51     self._driver_to_download_version = self._version if self._version not in (None, "latest") else self.get_latest_release_version()
#      52 return self._driver_to_download_version
#
# File c:\Users\Danil\anaconda3\lib\site-packages\webdriver_manager\drivers\chrome.py:62, in ChromeDriver.get_latest_release_version(self)
#      56 log(f"Get LATEST {self._name} version for {self._browser_type}")
#      57 latest_release_url = (
#      58     self._latest_release_url
#      59     if (self._version == "latest" or determined_browser_version is None)
#      60     else f"{self._latest_release_url}_{determined_browser_version}"
#      61 )
# ---> 62 resp = self._http_client.get(url=latest_release_url)
#      63 return resp.text.rstrip()
#
# File c:\Users\Danil\anaconda3\lib\site-packages\webdriver_manager\core\http.py:37, in WDMHttpClient.get(self, url, **kwargs)
#      35 except exceptions.ConnectionError:
#      36     raise ConnectionError(f"Could not reach host. Are you offline?")
# ---> 37 self.validate_response(resp)
#      38 if wdm_progress_bar():
#      39     show_download_progress(resp)
#
# File c:\Users\Danil\anaconda3\lib\site-packages\webdriver_manager\core\http.py:16, in HttpClient.validate_response(resp)
#      14 status_code = resp.status_code
#      15 if status_code == 404:
# ---> 16     raise ValueError(f"There is no such driver by url {resp.url}")
#      17 elif status_code == 401:
#      18     raise ValueError(f"API Rate limit exceeded. You have to add GH_TOKEN!!!")
#
# ValueError: There is no such driver by url https://chromedriver.storage.googleapis.com/LATEST_RELEASE_120.0.6099

# %%
driver.get("https://www.twitch.tv/72hrs")  # Replace with the desired URL
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# c:\Users\Danil\Documents\GitHub\twitch-chat-analytics\twitch_listener.ipynb Cell 3 line 1
# ----> <a href='vscode-notebook-cell:/c%3A/Users/Danil/Documents/GitHub/twitch-chat-analytics/twitch_listener.ipynb#W2sZmlsZQ%3D%3D?line=0'>1</a> driver.get("https://www.twitch.tv/72hrs")
#
# NameError: name 'driver' is not defined

# %%
processed_messages = set()
exception_count = 0

while True:
    try:
        # XPath for usernames and messages
        username_xpath = ".//span[contains(@class, 'chat-author__display-name')]"
        chat_message_xpath = "//span[contains(@class, 'text-fragment') and contains(@data-a-target, 'chat-message-text')]"

        # Find all usernames and chat messages
        usernames = driver.find_elements(By.XPATH, username_xpath)
        chat_messages = driver.find_elements(By.XPATH, chat_message_xpath)

        for username_element, chat_message_element in zip(usernames, chat_messages):
            message_id = hash(username_element.get_attribute("data-a-user") + chat_message_element.text)

            # Check if the message has been processed
            if message_id not in processed_messages:
                processed_messages.add(message_id)

                # Extract username and message
                username = username_element.get_attribute("data-a-user")
                chat_message = chat_message_element.text

                # Adding timestamp
                timestamp = datetime.now().strftime("%Y-%m-%d %H:%M:%S")

                # Creating JSON object
                comment_data = {
                    "comment_id": message_id,
                    "timestamp": timestamp,
                    "username": username,
                    "message": chat_message
                }

                print(json.dumps(comment_data))
                exception_count = 0

        # Wait before next iteration
        time.sleep(2)

    except NoSuchElementException:
        print("No Element Found")
        exception_count += 1
        if exception_count >= 2:
            # If multiple exceptions in a row, wait longer before next attempt
            time.sleep(5)
        else:
            time.sleep(2)

    except StaleElementReferenceException:
        print(f"Stale element reference for message, re-locating...")
        # Re-locate the element and retry or skip to the next one
        continue

    except Exception as e:
        print(f"Something went wrong: {e}")
        break
# Out:
# {"comment_id": -5107612672761691777, "timestamp": "2023-12-06 21:22:25", "username": "saoblow", "message": "we?"}
# {"comment_id": 638130502445135050, "timestamp": "2023-12-06 21:22:25", "username": "spikynext", "message": "this reminds me of my grandpa playing"}
# {"comment_id": 6122225024542403653, "timestamp": "2023-12-06 21:22:25", "username": "arcticnemesis", "message": "modCheck x2"}
# {"comment_id": -2478447371229054783, "timestamp": "2023-12-06 21:22:25", "username": "bloomguh", "message": "OMEGALAUGHING"}
# {"comment_id": 9028450787025406784, "timestamp": "2023-12-06 21:22:48", "username": "ayydee_44", "message": "old box LMAO"}
# {"comment_id": -7422389630935233394, "timestamp": "2023-12-06 21:22:48", "username": "fartwaves", "message": "surely im about to havve the biggest payout of my life"}
# {"comment_id": -7390432047928702395, "timestamp": "2023-12-06 21:22:48", "username": "john_chico_medallas", "message": "shittiest item in the game LMAO"}
# {"comment_id": 8367031922383730239, "timestamp": "2023-12-06 21:22:48", "username": "zugzugmine", "message": "any plans to play alex jones game"}
# Stale element reference for message, re-locating...
# {"comment_id": 3914166822007084468, "timestamp": "2023-12-06 21:23:00", "username": "ukiiyo", "message": "AlienPls"}
# {"comment_id": 1212783752411147383, "timestamp": "2023-12-06 21:23:00", "username": "thelahal", "message": "AlienPls alien is pleased"}
# {"comment_id": 7769663641183395824, "timestamp": "2023-12-06 21:23:00", "username": "leo6gm", "message": "COCKA"}
# {"comment_id": 7424873779282969811, "timestamp": "2023-12-06 21:23:00", "username": "pretty__tony", "message": "BOOMIES"}
# {"comment_id": 7836678486772001558, "timestamp": "2023-12-06 21:23:05", "username": "philliumtv", "message": "All in on believe EZ"}
# {"comment_id": 1215938574511526712, "timestamp": "2023-12-06 21:23:05", "username": "orange_bean", "message": "I just restart when that happens lmao"}
# {"comment_id": 5375452646899071066, "timestamp": "2023-12-06 21:23:05", "username": "gray0ne_", "message": "it's pretty good for sniper but yeah"}
# {"comment_id": -3783467067261189645, "timestamp": "2023-12-06 21:23:05", "username": "dreamerofsheep", "message": "shitty first legendary is an insta-reset"}
# Stale element reference for message, re-locating...
# {"comment_id": -6029845105061473360, "timestamp": "2023-12-06 21:23:11", "username": "the_hoblit", "message": "did moonmoon ever finish bg3"}
# {"comment_id": 782255511421997106, "timestamp": "2023-12-06 21:23:11", "username": "impurite", "message": "pikaMine choppin them bithces"}
# {"comment_id": -635932223300916473, "timestamp": "2023-12-06 21:23:11", "username": "the_hoblit", "message": "honour mode is out now"}
# {"comment_id": -488989705455937143, "timestamp": "2023-12-06 21:23:17", "username": "necrotized", "message": "AlienPls quite pleased AlienPls"}
# {"comment_id": -1083003750471076541, "timestamp": "2023-12-06 21:23:17", "username": "lichen_tv", "message": "I have 35 points but it won't let me bet 10 cause \"I don't have enough\""}
# {"comment_id": 7985723549043138493, "timestamp": "2023-12-06 21:23:17", "username": "necrotized", "message": "Grrr"}
# Stale element reference for message, re-locating...
# Stale element reference for message, re-locating...
# {"comment_id": -2259492495097376249, "timestamp": "2023-12-06 21:23:29", "username": "moon2coffee", "message": "DinkDonk"}
# {"comment_id": -1834626532604571021, "timestamp": "2023-12-06 21:23:29", "username": "gluteuscortex", "message": "\ud83d\udd14"}
# {"comment_id": 4527483188504776213, "timestamp": "2023-12-06 21:23:29", "username": "gluteuscortex", "message": "are u gonna try Deadbolt from same devs? its GIGA good"}
# {"comment_id": 5583702743930322069, "timestamp": "2023-12-06 21:23:29", "username": "vivi_", "message": "!cumbox"}
# {"comment_id": -5256087308842382415, "timestamp": "2023-12-06 21:23:30", "username": "badfoxtrot", "message": "farnsi opened a cumbox! There were 5 cums inside! \ud83d\udcc8 They now have 32 cums! borpaSpin"}
# {"comment_id": 4628703258867073174, "timestamp": "2023-12-06 21:24:02", "username": "fartwaves", "message": "I thought you said the wealth would trickle down"}
# {"comment_id": 2208830828843263671, "timestamp": "2023-12-06 21:24:02", "username": "dm8917", "message": "Classic"}
# {"comment_id": -7266402698608422735, "timestamp": "2023-12-06 21:24:02", "username": "jaylangis", "message": "ah from Rocky: First Blood"}
# {"comment_id": -3308596615768748735, "timestamp": "2023-12-06 21:24:02", "username": "philliumtv", "message": "gotta work on it big m"}
# {"comment_id": 3219883429458448431, "timestamp": "2023-12-06 21:24:02", "username": "hey__alright", "message": "SOYPOG"}
# {"comment_id": -1039543763377804143, "timestamp": "2023-12-06 21:24:02", "username": "zalkohd", "message": "imma poor fuck with 70k Sludge"}
# {"comment_id": 8536554508880373689, "timestamp": "2023-12-06 21:24:02", "username": "c60_jam", "message": "DUUR adoooooy"}
# {"comment_id": 8912504648397617916, "timestamp": "2023-12-06 21:24:02", "username": "thunderingroar", "message": "that one believer who put 250k on you winning the tech demo game has all the points"}
# {"comment_id": 2417823671461069127, "timestamp": "2023-12-06 21:24:02", "username": "brewserker96", "message": "That was actually offensive. Well done."}
# {"comment_id": 5537917542793457643, "timestamp": "2023-12-06 21:24:02", "username": "prospect_kvothe", "message": "KKonaW fake rambo"}
# {"comment_id": -9027056891197090066, "timestamp": "2023-12-06 21:24:02", "username": "xcompleasedad", "message": "Moon is the twitch version of Bernie"}
# {"comment_id": -3973024817959260733, "timestamp": "2023-12-06 21:24:02", "username": "chaosgodkhornes", "message": "giga gamba odds"}
# {"comment_id": -3885138484679129960, "timestamp": "2023-12-06 21:24:02", "username": "njgiantsfan", "message": "GIGA [57401]"}
# {"comment_id": -2023355781845162189, "timestamp": "2023-12-06 21:24:02", "username": "lichen_tv", "message": "is this a rerun? why is he not playing SoD"}
# {"comment_id": 5897210099964509387, "timestamp": "2023-12-06 21:24:02", "username": "nightbot", "message": "SLUDGE"}
# {"comment_id": -7597563430169212876, "timestamp": "2023-12-06 21:24:02", "username": "ryanlt", "message": "honestly we should call you jesse rambo"}
# {"comment_id": 6140579599693705605, "timestamp": "2023-12-06 21:24:02", "username": "thunderingroar", "message": "ty Obama"}
# {"comment_id": 6210392628735810291, "timestamp": "2023-12-06 21:24:02", "username": "bobevansmashpotatoes", "message": "WHAT THE line?"}
# {"comment_id": -7298457671029964481, "timestamp": "2023-12-06 21:24:03", "username": "commanderpepper", "message": "I've made 624k points without gambling and just by mostly silent chatting, it's a modest living but an honest one"}
# {"comment_id": -549771439769329472, "timestamp": "2023-12-06 21:24:03", "username": "gray0ne_", "message": "Do Rocky now."}
# {"comment_id": -5920013944023750080, "timestamp": "2023-12-06 21:24:03", "username": "kevnasteee", "message": "whoa i didn't know sly stallone was streaming"}
# {"comment_id": 4294528139431935142, "timestamp": "2023-12-06 21:24:03", "username": "kaprah", "message": "If streaming doesn't pop off for you, you can always be a voice actor"}
# {"comment_id": 1176632412713909956, "timestamp": "2023-12-06 21:24:03", "username": "hunterbush", "message": "nah that's hasan"}
# {"comment_id": 732120771244670610, "timestamp": "2023-12-06 21:24:03", "username": "kula_______", "message": "GAMBA"}
# {"comment_id": 8903161556270908271, "timestamp": "2023-12-06 22:03:57", "username": "ruffles___", "message": "chat should i donate to asianbunnyx so she could afford a shirt FeelsOkayMan"}
# {"comment_id": 81674690479253608, "timestamp": "2023-12-06 22:03:57", "username": "koji_64", "message": "these sentences from this markov individual makes no sense MAAAAN"}
# {"comment_id": 7642218661181982729, "timestamp": "2023-12-06 22:03:57", "username": "elvissmite", "message": "pepeJAM SHEESH"}
# {"comment_id": -3463988457253535397, "timestamp": "2023-12-06 22:03:57", "username": "james_peach", "message": "Good Evening Mr. Moon, have you given your official take on the acquisition of Juan Soto?"}
# {"comment_id": 8675654169888191386, "timestamp": "2023-12-06 22:03:57", "username": "astorath_the_grim_", "message": "venture into the unknown"}
# {"comment_id": 6854624804077151498, "timestamp": "2023-12-06 22:03:57", "username": "escaped_nil", "message": "LELW"}
# {"comment_id": -2621794340466643282, "timestamp": "2023-12-06 22:03:57", "username": "klubbah", "message": "FeelsStrongMan"}
# {"comment_id": 5665591715187681633, "timestamp": "2023-12-06 22:03:57", "username": "gluteuscortex", "message": "!discord"}
# {"comment_id": 5239324440425327252, "timestamp": "2023-12-06 22:03:57", "username": "unappreciatedmeme", "message": "FeelsStrongMan"}
# {"comment_id": -8495906893093752907, "timestamp": "2023-12-06 22:03:57", "username": "goodolpsycho", "message": "FeelsStrongMan"}
# {"comment_id": 9038746443634021740, "timestamp": "2023-12-06 22:03:57", "username": "leronasz", "message": "FeelsStrongMan"}
# {"comment_id": 8048707303691723970, "timestamp": "2023-12-06 22:03:57", "username": "eolrv", "message": "I dont"}
# {"comment_id": -417629851147433364, "timestamp": "2023-12-06 22:03:57", "username": "kodavaz", "message": "thats not true lol"}
# {"comment_id": -570201006134582632, "timestamp": "2023-12-06 22:03:57", "username": "goodolpsycho", "message": "D:"}
# {"comment_id": -1768154468140565125, "timestamp": "2023-12-06 22:03:57", "username": "that1butcher", "message": "I pull up twitch to watch football with the family last Thursday and they asked if it was a porn site after seeing the front page"}
# {"comment_id": 6513097015409055988, "timestamp": "2023-12-06 22:03:57", "username": "satan_2_", "message": "I know. MAAAAN its almost like he writes random chains of messages. Like he is some kind of marvels avengers bot"}
# {"comment_id": 5624639160683930045, "timestamp": "2023-12-06 22:03:57", "username": "jalmarkian", "message": "vodfriends if you want to see him get another win skip ahead by about 2 weeks"}
# {"comment_id": 8835249879046981385, "timestamp": "2023-12-06 22:03:57", "username": "egb5", "message": "marvel"}
# {"comment_id": 853518430791973548, "timestamp": "2023-12-06 22:03:57", "username": "ruffles___", "message": "its a different game mode"}
# {"comment_id": 8668014448263052930, "timestamp": "2023-12-06 22:03:57", "username": "slanderbot", "message": "not wrong"}
# {"comment_id": 9163074015601051623, "timestamp": "2023-12-06 22:03:57", "username": "necrotized", "message": "Slanderbot ah"}
# {"comment_id": 3245457437078997808, "timestamp": "2023-12-06 22:03:57", "username": "james_peach", "message": "don\u2019t use that kind of language"}
# {"comment_id": 2316899090722936984, "timestamp": "2023-12-06 22:03:57", "username": "randomuser68383", "message": "it's crazy how that shit gets pushed onto the front page like that Classic"}
# {"comment_id": -6579428600946123316, "timestamp": "2023-12-06 22:03:57", "username": "spaghettivictim", "message": "DinkDonk"}
# {"comment_id": 8780783711349285657, "timestamp": "2023-12-06 22:03:57", "username": "lxe97", "message": "this looks like Noita"}
# {"comment_id": -6524738330123606496, "timestamp": "2023-12-06 22:03:57", "username": "prodigywes", "message": "This music reminds me of Trons world in Kingdom Hearts 2 FeelsGoodMan"}
# {"comment_id": -1318475332480026518, "timestamp": "2023-12-06 22:03:57", "username": "tuxadracles", "message": "it's a game mode moon i was wrong"}
# {"comment_id": 8048443307513374867, "timestamp": "2023-12-06 22:03:58", "username": "james_peach", "message": "what setting"}
# {"comment_id": 1497266016258470626, "timestamp": "2023-12-06 22:03:58", "username": "necrotized", "message": "Sisi Artifact of command, he's not gonna use it"}
# {"comment_id": -845264950806425067, "timestamp": "2023-12-06 22:03:58", "username": "klubbah", "message": "did you turn down the 4watt setting"}
# {"comment_id": 6817162633046231337, "timestamp": "2023-12-06 22:03:58", "username": "desolatemirror", "message": "risk of rain 2 is easy channel points"}
# {"comment_id": 7443266003988840392, "timestamp": "2023-12-06 22:03:58", "username": "lazy_zz", "message": "LOADING"}
# {"comment_id": 6071619494766151691, "timestamp": "2023-12-06 22:03:58", "username": "mahtrousersnake", "message": "GIGA"}
# {"comment_id": -8400721310789519084, "timestamp": "2023-12-06 22:03:58", "username": "slanderbot", "message": "GIGA [57405]"}
# {"comment_id": -689036152501521674, "timestamp": "2023-12-06 22:03:58", "username": "nightbot", "message": "Zoom out big dawg"}
# {"comment_id": 3042343737495839485, "timestamp": "2023-12-06 22:03:58", "username": "theaussie", "message": "magma worms EZ"}
# {"comment_id": -3362209195649699159, "timestamp": "2023-12-06 22:03:58", "username": "fljqpy", "message": "ELPERMASSACRE where is the elper"}
# {"comment_id": 4840786686640565223, "timestamp": "2023-12-06 22:03:58", "username": "ki1ler7", "message": "HYPERNOPERS"}
# {"comment_id": -4230569900758447165, "timestamp": "2023-12-06 22:03:58", "username": "mantis__toboggan__", "message": "NOPERS"}
# {"comment_id": -4859884339647424034, "timestamp": "2023-12-06 22:03:58", "username": "bartho1omew13", "message": "NOPERS"}
# {"comment_id": 8497120789310846471, "timestamp": "2023-12-06 22:03:58", "username": "krueldestiny", "message": "ELPERMASSACRE"}
# {"comment_id": -5284981762125565741, "timestamp": "2023-12-06 22:03:58", "username": "bigdirtyphil", "message": "who play with they worm?"}
# {"comment_id": -7672214332382030512, "timestamp": "2023-12-06 22:04:02", "username": "fulmetljumpsuit", "message": "dont you die bitch"}
# {"comment_id": 6116006787841600127, "timestamp": "2023-12-06 22:04:02", "username": "ammomamo", "message": "HYPERNOPERS"}
# {"comment_id": -8599988619187566906, "timestamp": "2023-12-06 22:04:25", "username": "sj_clicky", "message": "EASY"}
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /Users/egehanyorulmaz/Projects/RTIS/final_project/listener_experiment.ipynb Cell 5 line 4
#      <a href='vscode-notebook-cell:/Users/egehanyorulmaz/Projects/RTIS/final_project/listener_experiment.ipynb#X10sZmlsZQ%3D%3D?line=36'>37</a>             exception_count = 0
#      <a href='vscode-notebook-cell:/Users/egehanyorulmaz/Projects/RTIS/final_project/listener_experiment.ipynb#X10sZmlsZQ%3D%3D?line=38'>39</a>     # Wait before next iteration
# ---> <a href='vscode-notebook-cell:/Users/egehanyorulmaz/Projects/RTIS/final_project/listener_experiment.ipynb#X10sZmlsZQ%3D%3D?line=39'>40</a>     time.sleep(2)
#      <a href='vscode-notebook-cell:/Users/egehanyorulmaz/Projects/RTIS/final_project/listener_experiment.ipynb#X10sZmlsZQ%3D%3D?line=41'>42</a> except NoSuchElementException:
#      <a href='vscode-notebook-cell:/Users/egehanyorulmaz/Projects/RTIS/final_project/listener_experiment.ipynb#X10sZmlsZQ%3D%3D?line=42'>43</a>     print("No Element Found")
#
# KeyboardInterrupt:

# %% [markdown]
# #### Websocketing

# %%
import asyncio
import websockets
import threading
from selenium import webdriver
from selenium.common.exceptions import NoSuchElementException, StaleElementReferenceException
import json
from datetime import datetime


drivers = {}
clients = set()


# Chat scraping function
async def scrape_chat(url):
    options = webdriver.ChromeOptions()
    options.add_argument("--headless")
    driver = webdriver.Chrome(options=options)
    drivers[url] = driver

    driver.get(url)
    processed_messages = set()

    while url in drivers:
        try:
            # XPath for usernames and messages
            username_xpath = ".//span[contains(@class, 'chat-author__display-name')]"
            chat_message_xpath = "//span[contains(@class, 'text-fragment') and contains(@data-a-target, 'chat-message-text')]"

            # Find all usernames and chat messages
            usernames = driver.find_elements(By.XPATH, username_xpath)
            chat_messages = driver.find_elements(By.XPATH, chat_message_xpath)

            for username_element, chat_message_element in zip(usernames, chat_messages):
                message_id = hash(username_element.get_attribute("data-a-user") + chat_message_element.text)

                # Check if the message has been processed
                if message_id not in processed_messages:
                    processed_messages.add(message_id)

                    # Extract username and message
                    username = username_element.get_attribute("data-a-user")
                    chat_message = chat_message_element.text

                    # Adding timestamp
                    timestamp = datetime.now().strftime("%Y-%m-%d %H:%M:%S")

                    # Creating JSON object
                    comment_data = {
                        "comment_id": message_id,
                        "timestamp": timestamp,
                        "username": username,
                        "message": chat_message
                    }

                    print(json.dumps(comment_data))
                    exception_count = 0

            # Wait before next iteration
            time.sleep(2)

        except NoSuchElementException:
            print("No Element Found")
            exception_count += 1
            if exception_count >= 2:
                # If multiple exceptions in a row, wait longer before next attempt
                time.sleep(5)
            else:
                time.sleep(2)

        except StaleElementReferenceException:
            print(f"Stale element reference for message, re-locating...")
            # Re-locate the element and retry or skip to the next one
            continue

        except Exception as e:
            print(f"Something went wrong: {e}")
            break

    # Cleanup
    driver.quit()
    del drivers[url]

# WebSocket server handlers
async def register(websocket):
    clients.add(websocket)

async def unregister(websocket):
    clients.remove(websocket)

async def broadcast_message(message):
    if clients:
        await asyncio.wait([client.send(message) for client in clients])

async def websocket_server(websocket, path):
    await register(websocket)
    try:
        async for message in websocket:
            if message not in drivers:
                asyncio.create_task(scrape_chat(message))  # Start scraping for new URL
            else:
                # Logic to handle existing URL or other commands
                pass
    finally:
        await unregister(websocket)

# Run the WebSocket server
def start_websocket_loop():
    loop = asyncio.new_event_loop()
    asyncio.set_event_loop(loop)

    server = websockets.serve(websocket_server, "localhost", 6789)
    loop.run_until_complete(server)
    loop.run_forever()

# Main execution
if __name__ == "__main__":
    threading.Thread(target=start_websocket_loop, daemon=True).start()

    # Keep the main thread alive or perform other tasks
    while True:
        # Perform any main-thread-specific tasks or simply keep it alive
        asyncio.sleep(10)
